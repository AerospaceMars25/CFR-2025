# %%
# copy and paste your lines of code from the previous notebook where you read in the data
import pandas as pd # remember we give a nickname to the packages we import

# %%
data = pd.read_csv('../Data/gaia_stars.csv') # the file is in a folder called "Data" so we add that to our path

# %%
# display the data
data
# Out:
#                    Star ID  Mass [Solar Mass]  Radius [Solar Radius]  \
# 0      5164707970261890560           0.811199               0.776116
# 1      6412595290592307840           0.739232               0.763127
# 2      4468557611984384512           0.825646               0.881947
# 3      2261614264931057664           0.828676               0.826463
# 4       425040000962559616           0.960048               1.143422
# ...                    ...                ...                    ...
# 40729   401012338992091520           1.365681               1.807146
# 40730  5995090693823761792           0.799427               0.861230
# 40731  5280799218287640448           3.302371              20.616924
# 40732  6234448087335108096           0.551528               0.535636
# 40733  4042240322113439104           0.711171               0.678837
#
#           g band     r band  Temperature [K]  Age [Gyr]
# 0       3.465752   2.842150        5002.0435   7.304041
# ...

# %% [markdown]
# **Copy and paste the table of the column explanations you started in the last notebook in this markdown cell**

# %% [markdown]
# ## Gaia data table
#
# Before we start using the data, let's take a look at the data preview above.
#
# **How many rows does this table have?**
#
# **Answer:** 40,734
#
#
# **How many columns does this table have?**
#
# **Answer:** 7
#
# Whenever we use data, it is important that we know both what the data is and what the units are for each variable. Below are the column names. We will **fill out** a definition for each column as we work through this notebook. First, let's identify the terms we might already know.
#
# | Column Header | Definition | Unit |
# | :- | :- | :- |
# | Star ID |  identifer of the star | no unit
# | Mass [Solar Mass] | weight; how much stuff it has | how many times the mass of our Sun a star is
# | Radius [Solar Radius] | physical size of star (width) | how many times the width of our Sun a star is
# | g band |how bright the star is in g filter | magnitude (bigger number is dimmer)
# | r band |how bright the star  is in r filter| magnitude (bigger number is dimmer)
# | Temperature [K]| how hot or cold | Kelvin (no negative)
# | Age [Gyr]| how old | billions of years (G = giga = billions)
#
# color = g band - r band

# %%
# create variables for mass, temperature, and age
mass = 1.0           # mass in solar masses
temperature = 5778   # temperature in Kelvin (e.g., Sun-like star)
age = 4.6            # age in billion years

# %% [markdown]
# ## Magnitudes
#
# We use "magnitudes" to describe how bright a star is. Remember, we mentioned that stars give off a lot of light. That light makes it to Earth, and we can measure how bright the star is from that light. The magnitude system was developed a long time ago, and unforunately, it is a weird scale. The higher a star's magnitude, the DIMMER it is. Bright stars have a low magnitude. (This is backwards from how I would personally do it! I try to remember this scale by saying the magnitude is the number of telescopes you'd need to see the star. If you need a high number, it must be dim.)
#
# There's another thing that is special about star light. It is a lot of different kinds of light! Humans can see the "visible light," and we feel what's called "infrared light" has heat. While our eyes can only process visible light, we can use machines to "see" the other kind of light coming from a star. We use "filters" to limit the light to a certain kind. This is similar to how wearing sunglasses block out light!
#
# When we look at a star using different filters, we see different features. Below are images of our Sun as seen through different filters.
#
# <center>
# <div>
# <img src='attachment:image.png' width=1000>
# <div>
# <center>

# %% [markdown]
# **What are different features you see across these images? Note that the color is not real, it is added to help distinguish the different kinds of light**
#
# **Response:** When I look at these images, I see that each filter shows different parts and activities on the Sun. In the HMI Dopplergram, I notice patterns that show the Sun’s movement on the surface. The HMI Magnetogram shows dark and light spots that represent the magnetic fields. The HMI Continuum looks most like the Sun I see in regular light, with visible sunspots. In the AIA 1700 Å and AIA 4500 Å images, I can see the surface texture of the Sun. The AIA 1600 Å and AIA 304 Å pictures show brighter areas where more activity is happening above the surface. When I look at AIA 171 Å, AIA 193 Å, and AIA 211 Å, I start to see loops and shapes coming off the Sun into the outer atmosphere, called the corona. The AIA 335 Å, AIA 094 Å, and AIA 131 Å images show very hot and active regions that look bright and stand out the most. Overall, I notice how each filter highlights different temperatures and layers, from the surface to the hotter, active areas higher up.

# %% [markdown]
# There are many different kinds of filters, but we will only be using two. They are called "g band" and "r band." Go back up to the table with the column names and fill out the rows for "g band" and "r band."
#
# After you fill out the table, we will also want to make variables for those data columns.

# %%
# creating variables for g band and r band

g_band = ""
r_band = ""

# %% [markdown]
# Make some plots!

# %%
# let's start by making a histogram of g

import matplotlib.pyplot as plt

# Extract the g band magnitudes
g_band = data['g band']

# Make the histogram with purple bars
plt.hist(g_band, bins=20, color='purple', edgecolor='black')
plt.xlabel('g band magnitude')
plt.ylabel('Number of stars')
plt.title('Histogram of g band magnitudes')
plt.show()

# %% [markdown]
# **Are the dimmer stars on the left or right of this plot?**
#
# **Answer:** The dimmer stars are on the right side of this plot because a higher magnitude number means the star is fainter.

# %%
# now a histogram of r
import matplotlib.pyplot as plt 

r_band= data['r band']

plt.hist(r_band, bins=20, color='darkorange',edgecolor='black')
plt.xlabel('r band magnitude')
plt.ylabel('Number of stars')
plt.title('Histogram of r band magnitudes')
plt.show()

# %% [markdown]
# **Are the dimmer stars on the left or right of this plot?**
#
# **Answer:** The dimmer stars are on the right side because higher magnitude numbers mean fainter stars.
#
# **Are these two histograms similar or different?**
#
# **Answer:** They are similar in shape, since the g band and r band magnitudes both measure brightness, but they might be slightly shifted because stars can appear brighter in one filter than the other depending on their color.

# %% [markdown]
# We can explore the relationship between brightness and mass by making a scatter plot.

# %%
# make a scatter plot where g vs mass (remember which goes on the y axis in that format)
# you might want to flip the y axis so the bigger numbers are at the bottom since that corresponds to dimmer stars (google how to)
import matplotlib.pyplot as plt

# We are not extracting mass and g band data 
mass= data ['Mass [Solar Mass]']
g_band = data['g band']

#Make the scatter plot 
plt.scatter(mass, g_band, color='black', edgecolor='red', alpha=0.5)

plt.xlabel('Mass [Solar Mass]')
plt.ylabel ('g band magnitude')
plt.title ('g band magnitude vs Mass')

#We now need to flip the y axis so brighter stars are at the top 
plt.gca().invert_yaxis() # this line of code will flip the y axis 
plt.show()

# %% [markdown]
# **According to your graph set up...**
#
# **What is the independent variable?**
#
# **Answer:** The independent variable is mass (in solar masses)
#
#
# **What is the dependent variable?**
#
# **Answer:** The depednent variable is g band magnitude (brightness)
#
#
# **What could a control variable be?**
#
# **Answer:** A control variable could be temperature or age of the stars. This will keep the factors constant when comparing mass and brightness of the stars.
#
# **What shapes or trends do you see in the data?**
#
# **Answer:** I see that, in general, the stars with the higher mass tend to be brighter (lower magnitude), althoug there is alot of scatter in the points. This creates a trend where the points are sort of sloping downward and this is because the x axis is flipped.

# %%
# now do the same thing for r band
import matplotlib.pyplot as plt

# Extract mass and r band data
mass = data['Mass [Solar Mass]']
r_band = data['r band']

# Make the scatter plot with red points and black edges
plt.scatter(mass, r_band, color='black', edgecolor='purple', alpha=0.5)

plt.xlabel('Mass [Solar Mass]')
plt.ylabel('r band magnitude')
plt.title('r band magnitude vs Mass')

# Flip the y-axis so brighter stars are at the top
plt.gca().invert_yaxis()

# %% [markdown]
# **Do you notice any large differences between these magnitudes?**
#
# **Answer:** I don’t notice any very large differences between these magnitudes overall. The r band and g band magnitudes look quite similar in their patterns because they both measure brightness, but in slightly different parts of the spectrum. Some individual stars may be brighter or dimmer in one filter compared to the other, but the overall trend with mass stays about the same.

# %% [markdown]
# ## Color
#
# Color is another thing astronomers define a little weirdly. We are used to seeing a color that our eyes can pick up. That color corresponds to a certain kind of light.
#
# Astronomers define color by subtracting the magnitudes in two different filters. For example, we could do g - r. That will give us a number, not what most people would call a color. We can say colors that are bigger than 0.6 are redder. And those that are smaller than 0.6 are bluer.

# %%
# calculate color and save the values to a 
color = g_band - r_band
data['color'] = color

# %%
# create a histogram of color
# add a vertical line at 0.6
# label to the left of this line "bluer" and to the right of the line "redder" (google how to add text on your plot)
import matplotlib.pyplot as plt

# Make the histogram
plt.hist(color, bins=30, color='black', edgecolor='t

# Add vertical line at 0.6
plt.axvline(x=0.6, color='black', linestyle='--')

# Add text labels
# plt.text(x, y, text, ...) adds text at the (x,y) coordinate on the plot
# Here, 0.2 is the x-position to the left of the line, and 0.7 is to the right
# plt.ylim()[1] gets the maximum y-value of the plot, so multiplying by 0.9 places the text near the top
plt.text(0.2, plt.ylim()[1]*0.9, 'bluer', fontsize=12, color='blue')
plt.text(0.7, plt.ylim()[1]*0.9, 'redder', fontsize=12, color='red')

plt.xlabel('Color (g - r)')
plt.ylabel('Number of stars')
plt.title('Histogram of Star Colors')

plt.show()

# %% [markdown]
# ## Deliverable
#
# Explore 2 potential relationships: color and temperature AND color and age. Make scatter plots with color on the y axis. Add in a horizontal line and labels to show which side of your graphs shows bluer stars and which shows redder. Make sure your axes are labeled and easy to read. Be ready to explain the trends you see.

# %%
# 1) color vs age scatter plot with redder and bluer labels at the division you used above
import matplotlib.pyplot as plt

# Extract age and color data
age = data['Age [Gyr]']

# Make the scatter plot
plt.scatter(age, color, color='black', edgecolor='coral', alpha=0.5)

plt.xlabel('Age [Gyr]')
plt.ylabel('Color (g - r)')
plt.title('Color vs Age')

# Add horizontal line at 0.6 to separate bluer/redder
plt.axhline(y=0.6, color='black', linestyle='--')

# Add text labels
# plt.text(x, y, label) puts text at (x,y)
plt.text(age.min(), 0.4, 'bluer', fontsize=12, color='blue')
plt.text(age.min(), 0.7, 'redder', fontsize=12, color='red')

plt.show()

# %% [markdown]
# **According to your graph set up...**
#
# **What is the independent variable?**
#
# **Answer:** Age (in Gyr).
#
# **What is the dependent variable?**
#
# **Answer:** Color (g-r)
#
# **What could a control variable be?**
#
# **Answer:** Temperature or mass of the stars
#
# **What shapes or trends do you see in the data?**
#
# **Answer:** In this Color vs Age scatter plot:Overall, there is a slight upward trend: as the age of the star increases, the color value tends to get larger. Stars with lower color values (below 0.6) are bluer, and those with higher color values (above 0.6) are redder.
# Many of the youngest stars (ages near 0) are bluer, while older stars are more often redder.
#
# **What does this mean physically?**
#
# **Answer:** Physically I think this suggests that as stars age, they cool and emit less blue light, shifting their color toward red.
# There is a lot of scatter in the points, meaning other factors like mass and temperature also affect the color, so not every star follows the trend exactly.

# %%
#2) color vs temperature scatter plot with redder and bluer labels at the division you used above

# %%
import matplotlib.pyplot as plt

# Extract temperature and color data
temperature = data['Temperature [K]']

# Make the scatter plot
plt.scatter(temperature, color, color='black', edgecolor='white', alpha=0.5)

plt.xlabel('Temperature [K]')
plt.ylabel('Color (g - r)')
plt.title('Color vs Temperature')

# Add horizontal line at 0.6
plt.axhline(y=0.6, color='black', linestyle='--')

# Add text labels
plt.text(temperature.min(), 0.4, 'bluer', fontsize=12, color='blue')
plt.text(temperature.min(), 0.7, 'redder', fontsize=12, color='red')

plt.show()

# %% [markdown]
# **According to your graph set up...**
#
# **What is the independent variable?**
#
# **Answer** Temperature
#
# **What is the dependent variable?**
#
# **Answer:** Color
#
# **What could a control variable be?**
#
# **Answer:** Age or mass
#
# **What shapes or trends do you see in the data?**
#
# **Answer:** In the Color vs Temperature scatter plot,There is a strong downward trend; as temperature increases, the color value decreases.
# Cooler stars (around 3000–5000 K) have higher color values (above 0.6), which means they are redder. Hotter stars (above 7000 K) have lower color values, meaning they are bluer.
# The data points form a clear slope, showing that temperature is strongly related to color.
#
# **What does this mean physically?**
#
# **Answer**: Physically, this means hotter stars emit more blue light, so their g - r color is smaller, while cooler stars emit more red light, giving them a higher color value.

# %%
# import our model fitting package -- don't edit the below code
from scipy.optimize import curve_fit
import numpy as np

# create a function for an inversely proportional model
def inversely_proportional(x, A):
    y = A / x
    return y

# define x and y data
x = data['Temperature [K]']
y = color

# apply the model to our data
popt, pcov = curve_fit(inversely_proportional, x, y)

# create model data
x_model = np.linspace(3000, 12000, 1000)
y_model = inversely_proportional(x_model, *popt)

# plot the model
plt.plot(x_model, y_model, color='blue', label='Inverse model')
plt.legend()

# %% [markdown]
# **Does the model appear to be a good fit? Would it have a high or low RMSE? Is the relationship between color and temperature a perfect inversely proportional fit?**
#
# **Answer:** the relationship between color and temperature is close to inversely proportional (because hotter stars are bluer), though not exact. This means the RMSE (root mean square error) would probably be moderate—not extremely low because the data points are spread out, but not very high either since the general slope matches.

# %% [markdown]
# ## Reflection
#
# We are going to move on from individual stars and start talking about large collections of stars. Before we do so, write down some notes in your lab notebook about what you've learned in this unit. Be sure to include some astronomy and some coding.
